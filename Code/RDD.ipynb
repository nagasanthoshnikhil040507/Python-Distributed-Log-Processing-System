# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("spark_test").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://NagaSanthosh:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>spark_test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Create a simple RDD from a list
data = [1, 2, 3, 4, 5]
rdd = sc.parallelize(data)

# %%
# Multiply each element by 2
rdd2 = rdd.map(lambda x: x * 2)

# %%
# Collect results to driver and print
result = rdd2.collect()
print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
# Assuming 'sc' (SparkContext) is already created

# Create an RDD from a list
data = [10, 20, 30, 40, 50]
rdd = sc.parallelize(data)

# Transformation: Add 5 to each element
rdd2 = rdd.map(lambda x: x + 5)

# Action: Collect and print
print(rdd2.collect())
# Out:
# [15, 25, 35, 45, 55]
